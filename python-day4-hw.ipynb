# %%
# Exercise 1 - Turn the shopping cart program from yesterday into an object-oriented program

# The comments in the cell below are there as a guide for thinking about the problem. However,

# if you feel a different way is best for you and your own thought process,

# please do what feels best for you by all means.


# Create a class called cart that retains items and has methods to add, remove, and show





class ShoppingCart:
    """"
    The cart will have a way to add, remove, show 
    and clear whatever is in your cart.
    
    Attributes in this class:
    -items: in a list form.
    A lot of this was from our daily work today.
    Going off of my HW from yesterday to follow outline.
    """
    
    def __init__(self, items):
        self.items = items
        
    def showCart(self):
        print('Your shopping cart has these items currently in it: ')
        for item in self.items:
            print(item)
            
    def addCart(self):
        groceries = input('What grocery item would you like to add? ')
        self.items.append(groceries)
        
    def removeCart(self):
        remove = input('What items would you like to remove? ')
        self.items.remove(remove)
        
        
ShoppingCart([])


def run():
    
    harmons = ShoppingCart([])
    while True:
        welcome = input('Welcome to Harmons, What would you like to do today? Add / Remove / Show / Checkout: ')
        
        if welcome.lower() == 'checkout':
            harmons.showCart()
            print('Here are your groceries! Thanks for shopping with us! -')
            break
        
        elif welcome.lower() == 'add':
            harmons.addCart()
            
        elif welcome.lower() == 'remove':
            harmons.removeCart
            
        elif welcome.lower() == 'show':
            print('Your shopping cart has these items in it: ')
            harmons.showCart()
            
        else:
            print('Try again...')
            
            
run()
            

cart.showCart()
cart.removeCart()
cart.addCart()




Exercise 2 - Write a Python class which has two methods get_String and print_String.
get_String accept a string from the user and print_String print the string in upper case

class Methodstring():
    def __init__(self):
        self.string = ""

    def getString(self):
        self.string = input()

    def printString(self):
        print(self.string.upper())

string = Methodstring()
string.getString()
string.printString()
